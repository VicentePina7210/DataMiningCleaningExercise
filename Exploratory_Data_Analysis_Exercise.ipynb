# %% [markdown]
# <a href="https://colab.research.google.com/github/VicentePina7210/DataMiningCleaningExercise/blob/main/Exploratory_Data_Analysis_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exploratory Data Analysis Exercise
#
# Explore the NYC Airbnb dataset. Write code to get insights on the NYC Airbnb dataset. Write code to answer the following code

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
# Helper code

# Create line graph
plt.plot(x, y)
plt.show()

# Create a scatter plot
plt.scatter(x, y)
plt.show()

# Create a histogram
plt.hist(x, bins=10)
plt.show()

# Create a bar plot
plt.bar(x, names=x_names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5ac64d02ebb7> in <cell line: 4>()
#       2
#       3 # Create line graph
# ----> 4 plt.plot(x, y)
#       5 plt.show()
#       6
#
# NameError: name 'x' is not defined

# %%
# Load the dataset
ab_df = pd.read_csv("/content/sample_data/AB_NYC_2019.csv")
#ab_df.head()
ab_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Warm up tasks

# %%
# Create a histogram of price
plt.hist(ab_df['price'], range=(0, 500), bins=100)

plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# Plot the relationship between reviews per month and price

plt.scatter(ab_df["number_of_reviews"], ab_df["price"])

# %%
# Create a bar plot of the room type
room_type = ab_df['room_type'].value_counts()


plt.figure(figsize=(8, 5))
room_type.plot(kind='bar')


plt.title('Room Type Distribution')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %%
# Create a bar plot for the average price for each year
avg = ab_df["price"].mean()

print (avg)
ab_df['neighbourhood_group'].unique()

for n_group in ["Brooklyn", "Manhattan", "Queens" , "Staten Island" , "Bronx"]:
  sub_ab_df = ab_df[ab_df['neighbourhood_group'] == n_group]
  plt.scatter(sub_ab_df['latitude'], sub_ab_df['longitude'], label=n_group)

plt.show()
# Out:
# 152.7206871868289

# %%
# Create a scatter plot of locations of listings using geo coordinates color coded by neighbourhood group
ab_df['neighbourhood_group'].unique()

for n_group in ["Brooklyn", "Manhattan", "Queens" , "Staten Island" , "Bronx"]:
  sub_ab_df = ab_df[ab_df['neighbourhood_group'] == n_group]
  plt.scatter(sub_ab_df['latitude'], sub_ab_df['longitude'], label=n_group)

plt.show()

# %% [markdown]
# ### Exploration questions

# %%
# How does the average price differ between various room types?
avg_price_per_room_type = ab_df.groupby('room_type')['price'].mean()

plt.bar(avg_price_per_room_type.index, avg_price_per_room_type.values, color='skyblue')
# Out:
# <BarContainer object of 3 artists>

# %%
# What is the distribution of rental prices across different neighborhoods?3
plt.figure(figsize=(10, 6))
ab_df.boxplot(column='price', by='neighbourhood', grid=False, showfliers=True)
# Out:
# <Axes: title={'center': 'price'}, xlabel='neighbourhood'>

# %%
# How does the minimum number of nights required impact the price of listings?

# %%
# How does the geographic distribution of listings correlate with prices?

# %% [markdown]
# ### Exploration
#
# Generate several more stats and plots and try to identify as many instances of the following as you can...
# 1. Groups or clusters that are not explicit
# 2. Anomalous, outliers, or unusual values
# 3. Potential associations or trends (over the years for example)

# %%
plt.title('Distribution of Minimum Nights Required')

plt.hist(ab_df['minimum_nights'], range=(0,20), bins=20,)
plt.xlabel('Minimum Nights')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(ab_df['number_of_reviews'], bins=20,range=(0,100), edgecolor='black')
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Reviews per Listing')
plt.show()
#check to see if the neighborhood makes a difference on reviews per listing

# %%
plt.hist(ab_df['calculated_host_listings_count'], bins=20,range = (0,10))
plt.xlabel('Number of Listings per Host')
plt.ylabel('Frequency')
plt.title('Distribution of Host Listings Count')
plt.show()
#could this possibly be an example of zipfs law? 20ish% of the host make up 80ish% of the listings
