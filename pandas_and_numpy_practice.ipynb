# %% [markdown]
# <a href="https://colab.research.google.com/github/VicentePina7210/DataMiningCleaningExercise/blob/main/pandas_and_numpy_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas and Numpy practice problems
# Write the code as indicated by the comments. When submitting the notebook, make sure anyone with the link can view.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas practice quesions

# %%
# Load data
house_df = pd.read_csv('/content/sample_data/california_housing_train.csv')
house_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# 1. Display the first 5 rows of the DataFrame.
# Hint: Use the appropriate Pandas function to inspect the first few rows.
house_df.head()
# 2. Show the names of all the columns in the DataFrame.
# Hint: Access the attribute that provides column names.
house_df.columns
# 3. Filter the DataFrame to show only rows where 'median_income' is greater than 2
filtered_df = house_df[house_df['median_income'] > 2]
# 4. Create a new column called 'rooms_per_household' by dividing the 'total_rooms' column by the 'households' column.
house_df["rooms_per_household"] = ( house_df['total_rooms'] / house_df['households'])
display(house_df)
# 5. Find the mean, median, and standard deviation of the 'median_house_value' column.
print((house_df['median_house_value']).mean())
print((house_df['median_house_value']).median())
print((house_df['median_house_value']).std())

# 6. Replace all missing values (`NaN`) in the 'total_bedrooms' column with the mean of that column.
house_df['total_bedrooms'] = house_df['total_bedrooms'].fillna(house_df['total_bedrooms'].mean())
# 7. Count how many unique values are in the 'housing_median_age' column.
unique_median_age = house_df['housing_median_age'].nunique()
# 8. Sort the DataFrame by the 'median_house_value' column in descending order and show the top 10 rows.
house_df.sort_values( by = 'median_house_value', ascending = False)
# 9. Select and display only the columns 'latitude', 'longitude', and 'median_house_value'.

# 10. Drop all rows where the 'total_bedrooms' column has missing values (`NaN`).

# 11. Rename the column 'median_house_value' to 'house_value_median'.

# 12. Find the number of rows in the DataFrame where the 'population' column is greater than 1000.

# 13. Create a new column called 'bedrooms_per_room' by dividing 'total_bedrooms' by 'total_rooms'.
# Hint: Ensure you handle potential division by zero errors.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# ## Numpy practice quesions

# %%
# 1. Create a 1D array with values from 0 to 20 (inclusive).
# Hint: Use np.arange.

# 2. Create a 3x3 matrix with values ranging from 1 to 9.
# Hint: Use np.arange and reshape.

# 3. Create a 5x5 identity matrix.
# Hint: Use np.eye.

# 4. Generate an array of 10 random floating-point numbers between 0 and 1.
# Hint: Use np.random.random.

# 5. Find the mean, median, and standard deviation of the array:
# [12, 15, 10, 20, 18, 14, 13, 19, 11].

# 6. Create a 1D array of 15 elements and reshape it into a 3x5 matrix.

# 7. Multiply two 2D arrays:
# Array A = [[1, 2], [3, 4]], Array B = [[2, 0], [1, 3]].

# 8. Find the index of the maximum and minimum values in the following array:
# [3, 7, 2, 8, 6, 4, 10, 1, 9].

# 9. Replace all values greater than 10 in the array [5, 12, 8, 21, 7, 14, 3] with 10.
